# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in d:\ai_ml\software\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\ai_ml\software\anaconda\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ai_ml\software\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ai_ml\software\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\ai_ml\software\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\ai_ml\software\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

print('Pandas version:', pd.__version__)
# Out:
# Pandas version: 2.3.3

# %%
emp = pd.Series(
    [10,20,40], index=['Ram','Shayam','Mohan'],name='employee List'
)
print(emp)
# Out:
# Ram       10
# Shayam    20
# Mohan     40
# Name: employee List, dtype: int64

# %% [markdown]
# #### Task 1 : Pandas Series Basics

# %%
import pandas as pd

marks = pd.Series([78,85,90,66,72])

# print values
print(marks)

# print index
print(marks.index)

# print data type
print(marks.dtype)

# access first element
print(marks[0])

# acess last two elemets
# print(marks[-2:])
print(marks.tail(2))
# Out:
# 0    78
# 1    85
# 2    90
# 3    66
# 4    72
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)
# int64
# 78
# 3    66
# 4    72
# dtype: int64

# %%
# print index
